# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Social_Network_Ads.csv")

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
X = df.iloc[:, [2, 3]].values
y = df.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25 , random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
X_train = std.fit_transform(X_train)
X_test - std.transform(X_test)
# Out:
# array([[3.08048021e+01, 8.69994950e+04],
#        [3.80125441e+01, 5.00005678e+04],
#        [3.53096408e+01, 7.49998430e+04],
#        [3.08048021e+01, 7.89997270e+04],
#        [3.53096408e+01, 5.00005678e+04],
#        [2.81018989e+01, 2.00014376e+04],
#        [3.17057699e+01, 1.50015825e+04],
#        [3.62106086e+01, 1.43997842e+05],
#        [1.99931892e+01, 6.80000459e+04],
#        [4.61212538e+01, 4.30007707e+04],
#        [3.08048021e+01, 4.90005968e+04],
#        [2.90028666e+01, 5.50004228e+04],
#        [3.71115763e+01, 5.50004228e+04],
#        [3.89135118e+01, 7.69997850e+04],
#        [2.17951247e+01, 8.59995240e+04],
#        [3.26067376e+01, 1.16998625e+05],
#        [3.71115763e+01, 7.69997850e+04],
#        [2.08941569e+01, 8.49995530e+04],
#        [5.33289958e+01, 1.29998248e+05],
#        [3.53096408e+01, 2.20013796e+04],
#        [3.53096408e+01, 4.70006548e+04],
#        [4.61212538e+01, 1.43997842e+05],
#        [4.07154473e+01, 5.10005388e+04],
#        [4.61212538e+01, 1.04998973e+05],
#        [2.44980279e+01, 2.80012056e+04],
#        [4.79231893e+01, 1.40997929e+05],
#        [2.90028666e+01, 8.69994950e+04],
#        [2.99038344e+01, 7.99996980e+04],
#        [3.71115763e+01, 6.20002199e+04],
#        [3.26067376e+01, 8.59995240e+04],
#        [2.26960924e+01, 8.79994660e+04],
#        [3.71115763e+01, 7.89997270e+04],
#        [5.51309313e+01, 6.00002779e+04],
#        [3.71115763e+01, 5.30004808e+04],
#        [2.53989956e+01, 5.80003358e+04],
#        [1.99931892e+01, 5.20005098e+04],
#        [2.35970601e+01, 8.09996690e+04],
#        [3.44086731e+01, 4.30007707e+04],
#        [3.17057699e+01, 3.40010317e+04],
#        [4.79231893e+01, 3.60009737e+04],
#        [2.81018989e+01, 8.79994660e+04],
#        [4.07154473e+01, 5.20005098e+04],
#        [2.81018989e+01, 8.39995820e+04],
#        [3.53096408e+01, 2.00014376e+04],
#        [4.25173828e+01, 1.11998770e+05],
#        [2.81018989e+01, 5.80003358e+04],
#        [3.71115763e+01, 7.99996980e+04],
#        [5.06260925e+01, 8.99994081e+04],
#        [2.72009311e+01, 3.00011476e+04],
#        [4.79231893e+01, 8.59995240e+04],
#        [5.51309313e+01, 1.21998480e+05],
#        [3.44086731e+01, 2.50012926e+04],
#        [3.53096408e+01, 5.70003648e+04],
#        [3.44086731e+01, 1.14998683e+05],
#        [5.69328668e+01, 8.79994660e+04],
#        [4.43193183e+01, 3.20010897e+04],
#        [2.99038344e+01, 8.29996110e+04],
#        [2.72009311e+01, 7.99996980e+04],
#        [4.79231893e+01, 2.80012056e+04],
#        [2.44980279e+01, 2.00014376e+04],
#        [3.26067376e+01, 1.80014956e+04],
#        [5.78338345e+01, 4.20007997e+04],
#        [2.08941569e+01, 7.59998140e+04],
#        [3.62106086e+01, 9.89991471e+04],
#        [2.08941569e+01, 2.60012636e+04],
#        [5.78338345e+01, 8.29996110e+04],
#        [2.53989956e+01, 8.89994370e+04],
#        [2.81018989e+01, 5.80003358e+04],
#        [3.98144796e+01, 4.70006548e+04],
#        [4.16164151e+01, 6.99999879e+04],
#        [3.26067376e+01, 1.49997668e+05],
#        [3.53096408e+01, 7.69997850e+04],
#        [2.35970601e+01, 6.30001909e+04],
#        [4.43193183e+01, 2.20013796e+04],
#        [2.81018989e+01, 8.89994370e+04],
#        [1.99931892e+01, 8.19996400e+04],
#        [4.16164151e+01, 7.89997270e+04],
#        [3.98144796e+01, 6.00002779e+04],
#        [5.15270603e+01, 3.40010317e+04],
#        [4.61212538e+01, 1.06998915e+05],
#        [5.60318990e+01, 1.43997842e+05],
#        [5.69328668e+01, 8.29996110e+04],
#        [2.53989956e+01, 5.50004228e+04],
#        [2.72009311e+01, 3.50010027e+04],
#        [5.60318990e+01, 3.80009157e+04],
#        [4.16164151e+01, 7.99996980e+04],
#        [3.98144796e+01, 7.49998430e+04],
#        [5.69328668e+01, 1.29998248e+05],
#        [4.52202861e+01, 4.10008287e+04],
#        [4.07154473e+01, 6.00002779e+04],
#        [4.16164151e+01, 6.40001619e+04],
#        [3.71115763e+01, 1.45997784e+05],
#        [2.44980279e+01, 4.80006258e+04],
#        [2.62999634e+01, 3.30010607e+04],
#        [2.53989956e+01, 8.39995820e+04],
#        [2.81018989e+01, 9.59992341e+04],
#        [2.44980279e+01, 6.30001909e+04],
#        [4.70222215e+01, 3.30010607e+04],
#        [4.70222215e+01, 8.99994081e+04],
#        [4.16164151e+01, 1.03999002e+05]])

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion = "gini" , random_state= 42, max_depth=7)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
data = pd.DataFrame(y)

# %%
data.value_counts()
# Out:
# 0
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 0, 68],
#        [ 0, 32]])

# %%
clfr = classification_report(y_test, y_pred)
# Out:
# c:\Users\LENOVO\Desktop\Machine learning\venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\LENOVO\Desktop\Machine learning\venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\LENOVO\Desktop\Machine learning\venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
clfr
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.00      0.00      0.00        68\n           1       0.32      1.00      0.48        32\n\n    accuracy                           0.32       100\n   macro avg       0.16      0.50      0.24       100\nweighted avg       0.10      0.32      0.16       100\n'

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_0 <= 0.63
# |   |--- feature_1 <= 0.61
# |   |   |--- feature_0 <= -0.16
# |   |   |   |--- class: 0
# |   |   |--- feature_0 >  -0.16
# |   |   |   |--- feature_1 <= 0.40
# |   |   |   |   |--- feature_1 <= -0.06
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  -0.06
# |   |   |   |   |   |--- feature_1 <= 0.03
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_1 >  0.03
# |   |   |   |   |   |   |--- feature_1 <= 0.26
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.26
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  0.40
# |   |   |   |   |--- class: 1
# |   |--- feature_1 >  0.61
# |   |   |--- feature_0 <= -1.15
# |   |   |   |--- class: 0
# |   |   |--- feature_0 >  -1.15
# |   |   |   |--- feature_1 <= 1.36
# |   |   |   |   |--- feature_1 <= 1.10
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_1 >  1.10
# |   |   |   |   |   |--- feature_0 <= -0.46
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  -0.46
# |   |   |   |   |   |   |--- feature_0 <= -0.36
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  -0.36
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  1.36
# |   |   |   |   |--- feature_0 <= 0.43
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  0.43
# |   |   |   |   |   |--- feature_1 <= 1.78
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_1 >  1.78
# |   |   |   |   |   |   |--- feature_0 <= 0.53
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  0.53
# |   |   |   |   |   |   |   |--- class: 1
# |--- feature_0 >  0.63
# |   |--- feature_0 <= 0.83
# |   |   |--- feature_1 <= -0.51
# |   |   |   |--- feature_1 <= -1.37
# |   |   |   |   |--- feature_0 <= 0.73
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  0.73
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  -1.37
# |   |   |   |   |--- class: 1
# |   |   |--- feature_1 >  -0.51
# |   |   |   |--- feature_1 <= 1.07
# |   |   |   |   |--- feature_1 <= 0.20
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  0.20
# |   |   |   |   |   |--- feature_0 <= 0.73
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  0.73
# |   |   |   |   |   |   |--- feature_1 <= 0.32
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  0.32
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  1.07
# |   |   |   |   |--- class: 1
# |   |--- feature_0 >  0.83
# |   |   |--- feature_1 <= -0.81
# |   |   |   |--- class: 1
# |   |   |--- feature_1 >  -0.81
# |   |   |   |--- feature_1 <= -0.71
# |   |   |   |   |--- feature_0 <= 2.12
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  2.12
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_1 >  -0.71
# |   |   |   |   |--- feature_0 <= 1.42
# |   |   |   |   |   |--- feature_1 <= -0.63
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  -0.63
# |   |   |   |   |   |   |--- feature_0 <= 1.03
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  1.03
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  1.42
# |   |   |   |   |   |--- class: 1

# %%
fig = plt.figure(figsize=(25,20))
tree.plot_tree(clf)
# Out:
# [Text(0.4375, 0.9375, 'x[0] <= 0.631\ngini = 0.466\nsamples = 300\nvalue = [189, 111]'),
#  Text(0.16071428571428573, 0.8125, 'x[1] <= 0.606\ngini = 0.303\nsamples = 215\nvalue = [175, 40]'),
#  Text(0.29910714285714285, 0.875, 'True  '),
#  Text(0.07142857142857142, 0.6875, 'x[0] <= -0.161\ngini = 0.076\nsamples = 176\nvalue = [169, 7]'),
#  Text(0.03571428571428571, 0.5625, 'gini = 0.0\nsamples = 114\nvalue = [114, 0]'),
#  Text(0.10714285714285714, 0.5625, 'x[1] <= 0.403\ngini = 0.2\nsamples = 62\nvalue = [55, 7]'),
#  Text(0.07142857142857142, 0.4375, 'x[1] <= -0.06\ngini = 0.153\nsamples = 60\nvalue = [55, 5]'),
#  Text(0.03571428571428571, 0.3125, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.10714285714285714, 0.3125, 'x[1] <= 0.027\ngini = 0.285\nsamples = 29\nvalue = [24, 5]'),
#  Text(0.07142857142857142, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14285714285714285, 0.1875, 'x[1] <= 0.259\ngini = 0.245\nsamples = 28\nvalue = [24, 4]'),
#  Text(0.10714285714285714, 0.0625, 'gini = 0.298\nsamples = 22\nvalue = [18, 4]'),
#  Text(0.17857142857142858, 0.0625, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.14285714285714285, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25, 0.6875, 'x[0] <= -1.151\ngini = 0.26\nsamples = 39\nvalue = [6, 33]'),
#  Text(0.21428571428571427, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2857142857142857, 0.5625, 'x[1] <= 1.36\ngini = 0.229\nsamples = 38\nvalue = [5, 33]'),
#  Text(0.21428571428571427, 0.4375, 'x[1] <= 1.099\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.17857142857142858, 0.3125, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.25, 0.3125, 'x[0] <= -0.458\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.21428571428571427, 0.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2857142857142857, 0.1875, 'x[0] <= -0.359\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.25, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32142857142857145, 0.0625, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.35714285714285715, 0.4375, 'x[0] <= 0.433\ngini = 0.083\nsamples = 23\nvalue = [1, 22]'),
#  Text(0.32142857142857145, 0.3125, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.39285714285714285, 0.3125, 'x[1] <= 1.781\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.35714285714285715, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42857142857142855, 0.1875, 'x[0] <= 0.532\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.39285714285714285, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4642857142857143, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7142857142857143, 0.8125, 'x[0] <= 0.829\ngini = 0.275\nsamples = 85\nvalue = [14, 71]'),
#  Text(0.5758928571428572, 0.875, '  False'),
#  Text(0.6071428571428571, 0.6875, 'x[1] <= -0.51\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.5357142857142857, 0.5625, 'x[1] <= -1.365\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5, 0.4375, 'x[0] <= 0.73\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4642857142857143, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5357142857142857, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5714285714285714, 0.4375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6785714285714286, 0.5625, 'x[1] <= 1.07\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.6428571428571429, 0.4375, 'x[1] <= 0.201\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.6071428571428571, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6785714285714286, 0.3125, 'x[0] <= 0.73\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6428571428571429, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7142857142857143, 0.1875, 'x[1] <= 0.317\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6785714285714286, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.75, 0.0625, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7142857142857143, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8214285714285714, 0.6875, 'x[1] <= -0.814\ngini = 0.205\nsamples = 69\nvalue = [8, 61]'),
#  Text(0.7857142857142857, 0.5625, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.8571428571428571, 0.5625, 'x[1] <= -0.713\ngini = 0.292\nsamples = 45\nvalue = [8, 37]'),
#  Text(0.7857142857142857, 0.4375, 'x[0] <= 2.117\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.75, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8214285714285714, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9285714285714286, 0.4375, 'x[0] <= 1.423\ngini = 0.245\nsamples = 42\nvalue = [6, 36]'),
#  Text(0.8928571428571429, 0.3125, 'x[1] <= -0.626\ngini = 0.397\nsamples = 22\nvalue = [6, 16]'),
#  Text(0.8571428571428571, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9285714285714286, 0.1875, 'x[0] <= 1.027\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(0.8928571428571429, 0.0625, 'gini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.9642857142857143, 0.0625, 'gini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.9642857142857143, 0.3125, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]')]
