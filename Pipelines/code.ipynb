# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pipeline is a mechanism which chains together multiple steps so that the output of each step is used as input to the next step
#
# Pipelines makes it easy to apply the same preprocessing to train and test

# %% [markdown]
# Like if we have mising values + categorical input then we first fill the missing val;ues and encode the categorical variables and then only train. So, They need multiple steps to implement but pipelining makes it easy to implement these all in a single step

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("train.csv")

# %%
df.drop(["PassengerId","Name","Ticket","Cabin"], inplace = True, axis = 1)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
X_train, X_test, y_train , y_test = train_test_split(df.drop(columns = "Survived"),
                                                    df["Survived"],
                                                     test_size=0.2,
                                                      random_state=13 )
