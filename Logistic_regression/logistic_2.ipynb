# %% [markdown]
# Sigmoid function

# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=30)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
def step(z):
    return 1 if z>0 else 0

# %%
def perceptron(X,y):
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]

# %%
intercept_,coef_ = perceptron(X,y)

# %%
print(coef_)
print(intercept_)
# Out:
# [1.1204053  0.40381514]
# 1.2000000000000002

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %% [markdown]
# In this perceptron trick, when the points are classified right it stops ,and it only changes the orientation of thwe line whenever the point is misplaced such that it doesnt create equilibrium or symmetry between the data points.
#
# Because when the step fucntion is called it gives 1 or 0 which can change the whole learning rate term to 0 and no change is brought to the orientation of the line and the weights are same as the old weights

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()
lor.fit(X,y)
# Out:
# LogisticRegression()

# %%
m = -(lor.coef_[0][0]/lor.coef_[0][1])
b = -(lor.intercept_/lor.coef_[0][1])

# %%
x_input1 = np.linspace(-3,3,100)
y_input1 = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.plot(x_input1,y_input1,color='black',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %% [markdown]
# This is the logistic regression algorithm from the Scikit-learn library which gives the optimal solution of the logistic regression by dividing the sapce and classifying the data points according to the symmetry such that they both are equally separated

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %% [markdown]
# Here, the Step function is replaced by the sigmoid function suich that a change is brought in the line even if the predict of the model and given dataset is correct.....
#
# there Z is the parameter which takes on the dot product between the X and the weights and the sigmoid function instead of returning of 0 and 1 it returns a number if Z is extremely large then function returns the valuue closer to 1
# else if z is smaller then it returns value closer to 0
#
# means z can range - inf to inf
# where as sigmoid returns 0 to 1
#
# In the line the sigmoid function value if 0.5 if z = 0

# %%
def perceptron(X,y):
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = sigmoid(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]

# %%
intercept_,coef_ = perceptron(X,y)
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input2 = np.linspace(-3,3,100)
y_input2 = m*x_input + b
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.plot(x_input1,y_input1,color='black',linewidth=3)
plt.plot(x_input2,y_input2,color='brown',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
def perceptron(X,y):
    
    m = []
    b = []
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(200):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
        m.append(-(weights[1]/weights[2]))
        b.append(-(weights[0]/weights[2]))
        
    return m,b

# %%
m,b = perceptron(X,y)

# %%
print(m,b)
